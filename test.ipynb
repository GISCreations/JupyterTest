# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/GISCreations/JupyterTest/blob/main/Users/owenbales/Downloads/project/JupyterTest.ipynb)

# %%
print("What's up, doc?")

# %% [markdown]
# # This is a jupyter notebook!
